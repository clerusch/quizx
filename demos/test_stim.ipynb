# %%
import quizx
import stim

# %%
stimcode = quizx.zx2stim_py("../test_files/steane_style_steane_2_rounds.zxg")
print(stimcode)
# Out:
# TICK
# H 1 # mapped from qubit -3
# H 4 # mapped from qubit -0
# H 2 # mapped from qubit -2
# TICK
# TICK
# CNOT 4 11 # mapped from qubits -0 8
# TICK
# TICK
# CNOT 1 6 # mapped from qubits -3 3
# TICK
# TICK
# CNOT 2 5 # mapped from qubits -2 2
# CNOT 1 0 # mapped from qubits -3 -4
# TICK
# TICK
# CNOT 2 1 # mapped from qubits -2 -3
# TICK
# CNOT 1 3 # mapped from qubits -3 -1
# TICK
# CNOT 4 2 # mapped from qubits -0 -2
# TICK
# TICK
# CNOT 1 4 # mapped from qubits -3 -0
# TICK
# CNOT 2 3 # mapped from qubits -2 -1
# TICK
# CNOT 4 0 # mapped from qubits -0 -4
# TICK
# TICK
# CNOT 4 10 # mapped from qubits -0 7
# CNOT 2 0 # mapped from qubits -2 -4
# TICK
# CNOT 3 9 # mapped from qubits -1 6
# TICK
# CNOT 2 8 # mapped from qubits -2 5
# TICK
# TICK
# CNOT 1 7 # mapped from qubits -3 4
# TICK
# TICK
# H 1 # mapped from qubit -3
# MR 1 # mapped from qubit -3
# H 2 # mapped from qubit -2
# MR 2 # mapped from qubit -2
# H 3 # mapped from qubit -1
# MR 3 # mapped from qubit -1
# ...

# %%
circ = stim.Circuit(stimcode)
print(circ.diagram())
result = circ.compile_sampler().sample(shots=20)
print(result[0])
# Out:
#                                                     /---------------------------------------\                                             /-----------------\                                             /-------------------------------------------\                                             /----------\   /-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------\
# ...
